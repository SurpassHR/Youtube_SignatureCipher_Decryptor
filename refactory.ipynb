# %%
import requests

# %%
url = "https://www.youtube.com/watch?v=mgO38dJ9NuU"
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
}
req = requests.get(url=url, params=header)

# %%
respStatusCode = req.status_code
respContent = req.text
print("status code: {}".format(respStatusCode))
print("content: {}".format(respContent))
# Out:
# status code: 200
# content: <!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="xSFSyUEC-r8iybky3yP9Ww">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="xSFSyUEC-r8iybky3yP9Ww">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(respContent, "html.parser")
prettierHtml = soup.prettify()
print(prettierHtml)
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <script data-id="_gd" nonce="xSFSyUEC-r8iybky3yP9Ww">
#    window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/>
#   <script nonce="xSFSyUEC-r8iybky3yP9Ww">
# ...

# %%
title = soup.title
print("title: {}".format(title))
titleContent = title.string
print("titleContent: {}".format(titleContent))
pLabel = soup.p
print("pLabel: {}".format(pLabel))
aLabel = soup.a.prettify()
print("aLabel: {}".format(aLabel))
print("aLabel size: {}".format(len(aLabel)))
allALabel = soup.find_all("a")
print("a label number: {}".format(len(aLabelList)))
# Out:
# title: <title>Just cruising in Night City - YouTube</title>
# titleContent: Just cruising in Night City - YouTube
# pLabel: None
# aLabel: <a href="/" style="display: none;" title="YouTube">
#  <svg class="external-icon" id="yt-logo-updated-svg" viewbox="0 0 90 20">
#   <g id="yt-logo-updated" preserveaspectratio="xMidYMid meet" viewbox="0 0 90 20">
#    <g>
#     <path d="M27.9727 3.12324C27.6435 1.89323 26.6768 0.926623 25.4468 0.597366C23.2197 2.24288e-07 14.285 0 14.285 0C14.285 0 5.35042 2.24288e-07 3.12323 0.597366C1.89323 0.926623 0.926623 1.89323 0.597366 3.12324C2.24288e-07 5.35042 0 10 0 10C0 10 2.24288e-07 14.6496 0.597366 16.8768C0.926623 18.1068 1.89323 19.0734 3.12323 19.4026C5.35042 20 14.285 20 14.285 20C14.285 20 23.2197 20 25.4468 19.4026C26.6768 19.0734 27.6435 18.1068 27.9727 16.8768C28.5701 14.6496 28.5701 10 28.5701 10C28.5701 10 28.5677 5.35042 27.9727 3.12324Z" fill="#FF0000">
#     </path>
# ...

# %%
scripts = soup.find_all("script")
ytplayer = ""
for script in scripts:
    if "ytplayer" in str(script) and "ytcfg" in str(script):
        ytplayer = str(script)

# %%
ytplayerSoup = bs(ytplayer)
ytplayerCfg = ytplayerSoup.string
ytplayerCfg = ytplayerCfg.replace(",", ",\n")
print(ytplayerCfg)
# Out:
# (function() {window.ytplayer={};
# ytcfg.set({"CLIENT_CANARY_STATE":"none",
# "DEVICE":"cbrand\u003dpython\u0026ceng\u003dUSER_DEFINED\u0026cmodel\u003drequests\u0026cplatform\u003dDESKTOP",
# "DISABLE_YT_IMG_DELAY_LOADING":false,
# "ELEMENT_POOL_DEFAULT_CAP":75,
# "EVENT_ID":"QVlGZdTsDrHBsfIP0PSRgAc",
# "EXPERIMENT_FLAGS":{"H5_enable_full_pacf_logging":true,
# "H5_use_async_logging":true,
# "ab_det_apb_b":true,
# "ab_det_fet_wr":true,
# "ab_det_fet_wr_en":true,
# "ab_det_gen_re":true,
# "action_companion_center_align_description":true,
# "allow_skip_networkless":true,
# "att_web_record_metrics":true,
# "autoescape_tempdata_url":true,
# "browse_next_continuations_migration_playlist":true,
# "c3_watch_page_component":true,
# "cache_utc_offset_minutes_in_pref_cookie":true,
# "cancel_pending_navs":true,
# "check_user_lact_at_prompt_shown_time_on_web":true,
# "clear_user_partitioned_ls":true,
# "client_respect_autoplay_switch_button_renderer":true,
# "cold_missing_history":true,
# ...

# %%
import re

# %%
ytplayerCfgList = re.findall("ytcfg\.set\(\{(.*?)\}\);", ytplayerCfg, flags=re.S)
if ytplayerCfgList and len(ytplayerCfgList) == 1:
    ytplayerCfgList = ytplayerCfgList[0]
ytplayerCfgList = ytplayerCfgList.replace("\n", "").replace("true", "True").replace("false", "False")
ytplayerCfgList = ytplayerCfgList.encode().decode("unicode_escape")
print(ytplayerCfgList)
# Out:
# "CLIENT_CANARY_STATE":"none","DEVICE":"cbrand=python&ceng=USER_DEFINED&cmodel=requests&cplatform=DESKTOP","DISABLE_YT_IMG_DELAY_LOADING":False,"ELEMENT_POOL_DEFAULT_CAP":75,"EVENT_ID":"QVlGZdTsDrHBsfIP0PSRgAc","EXPERIMENT_FLAGS":{"H5_enable_full_pacf_logging":True,"H5_use_async_logging":True,"ab_det_apb_b":True,"ab_det_fet_wr":True,"ab_det_fet_wr_en":True,"ab_det_gen_re":True,"action_companion_center_align_description":True,"allow_skip_networkless":True,"att_web_record_metrics":True,"autoescape_tempdata_url":True,"browse_next_continuations_migration_playlist":True,"c3_watch_page_component":True,"cache_utc_offset_minutes_in_pref_cookie":True,"cancel_pending_navs":True,"check_user_lact_at_prompt_shown_time_on_web":True,"clear_user_partitioned_ls":True,"client_respect_autoplay_switch_button_renderer":True,"cold_missing_history":True,"compress_gel":True,"config_age_report_killswitch":True,"csi_on_gel":True,"decorate_autoplay_renderer":True,"defer_menus":True,"defer_overlays":True,"defer_
# ...

# %%
ytplayerCfgDict = eval("{" + ytplayerCfgList + "}")
ytplayerCfgJson = json.loads(json.dumps(ytplayerCfgDict))
print(ytplayerCfgJson.keys())
print(ytplayerCfgJson.values())
print(ytplayerCfgJson.get("EXPERIMENT_FLAGS").get('H5_enable_full_pacf_logging'))
# Out:
# dict_keys(['CLIENT_CANARY_STATE', 'DEVICE', 'DISABLE_YT_IMG_DELAY_LOADING', 'ELEMENT_POOL_DEFAULT_CAP', 'EVENT_ID', 'EXPERIMENT_FLAGS', 'GAPI_HINT_PARAMS', 'GAPI_HOST', 'GAPI_LOCALE', 'GL', 'GOOGLE_FEEDBACK_PRODUCT_ID', 'GOOGLE_FEEDBACK_PRODUCT_DATA', 'HL', 'HTML_DIR', 'HTML_LANG', 'INNERTUBE_API_KEY', 'INNERTUBE_API_VERSION', 'INNERTUBE_CLIENT_NAME', 'INNERTUBE_CLIENT_VERSION', 'INNERTUBE_CONTEXT', 'INNERTUBE_CONTEXT_CLIENT_NAME', 'INNERTUBE_CONTEXT_CLIENT_VERSION', 'INNERTUBE_CONTEXT_GL', 'INNERTUBE_CONTEXT_HL', 'LATEST_ECATCHER_SERVICE_TRACKING_PARAMS', 'LOGGED_IN', 'PAGE_BUILD_LABEL', 'PAGE_CL', 'scheduler', 'SERVER_NAME', 'SESSION_INDEX', 'SIGNIN_URL', 'VISITOR_DATA', 'WEB_PLAYER_CONTEXT_CONFIGS', 'XSRF_FIELD_NAME', 'XSRF_TOKEN', 'YPC_MB_URL', 'YTR_FAMILY_CREATION_URL', 'SERVER_VERSION', 'REUSE_COMPONENTS', 'STAMPER_STABLE_LIST', 'DATASYNC_ID', 'SERIALIZED_CLIENT_CONFIG_DATA', 'LIVE_CHAT_BASE_TANGO_CONFIG', 'FEXP_EXPERIMENTS', 'LIVE_CHAT_SEND_MESSAGE_ACTION', 'ROOT_VE_TYPE', 'CL
# ...
